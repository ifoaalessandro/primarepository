# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px 
df=pd.read_csv("https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/Company.csv",sep=",")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
X =df.drop(columns='Sales')
y =df['Sales']

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.25, 
                                                    random_state = 667
                                                    )

# %%
X_train.shape, X_test.shape
# Out:
# ((150, 3), (50, 3))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(fit_intercept=True)
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_
model.intercept_
y_pred = model.predict(X_test)

# %%
res_df = pd.DataFrame(data=list(zip(y_pred, y_test)),columns=['predicted', 'real'])
res_df
# Out:
#     predicted  real
# 0   20.385544  22.4
# 1   13.270625  13.2
# 2    9.840452  10.1
# 3    9.371454   9.7
# 4   13.902022  14.6
# 5   10.194711  10.5
# 6   18.185120  18.4
# 7   21.083449  21.5
# 8    9.826397  10.1
# 9   10.592440  11.3
# 10  16.586915  17.3
# 11  21.387707  20.2
# 12   7.061777   5.6
# 13  11.459483  12.3
# 14  18.702574  19.8
# 15   7.759159   8.1
# 16  15.964048  16.4
# 17  15.443888  15.9
# 18   8.594803   8.4
# 19  12.470190  10.3
# 20   8.875350   9.4
# 21   8.994764  11.9
# 22  24.908884  26.2
# 23  20.760390  23.7
# 24  10.907925  11.3
# 25  12.185855  12.9
# 26   8.304853   8.7
# 27  18.880481  17.0
# 28  21.407791  16.1
# 29  13.993424  14.7
# 30   6.300533   6.9
# 31  22.215383  22.2
# 32   7.105490   7.6
# 33   9.698797   9.2
# 34  17.848858  17.1
# 35  11.268248  10.4
# 36  20.618843  22.6
# 37   7.400877   6.6
# 38   8.756179   8.5
# 39  15.788710  15.6
# 40  20.191986  19.6
# 41  11.010208  10.9
# 42   9.225657   7.3
# 43  22.133427  23.2
# 44  17.083018  16.6
# 45  15.033804  15.2
# 46  16.701916  19.7
# 47  10.251219   8.7
# 48  12.453942  10.3
# 49  17.784928  16.9

# %%
res_df['error'] = res_df['real'] - res_df['predicted']
res_df
# Out:
#     predicted  real     error
# 0   20.385544  22.4  2.014456
# 1   13.270625  13.2 -0.070625
# 2    9.840452  10.1  0.259548
# 3    9.371454   9.7  0.328546
# 4   13.902022  14.6  0.697978
# 5   10.194711  10.5  0.305289
# 6   18.185120  18.4  0.214880
# 7   21.083449  21.5  0.416551
# 8    9.826397  10.1  0.273603
# 9   10.592440  11.3  0.707560
# 10  16.586915  17.3  0.713085
# 11  21.387707  20.2 -1.187707
# 12   7.061777   5.6 -1.461777
# 13  11.459483  12.3  0.840517
# 14  18.702574  19.8  1.097426
# 15   7.759159   8.1  0.340841
# 16  15.964048  16.4  0.435952
# 17  15.443888  15.9  0.456112
# 18   8.594803   8.4 -0.194803
# 19  12.470190  10.3 -2.170190
# 20   8.875350   9.4  0.524650
# 21   8.994764  11.9  2.905236
# 22  24.908884  26.2  1.291116
# 23  20.760390  23.7  2.939610
# 24  10.907925  11.3  0.392075
# 25  12.185855  12.9  0.714145
# 26   8.304853   8.7  0.395147
# 27  18.880481  17.0 -1.880481
# 28  21.407791  16.1 -5.307791
# 29  13.993424  14.7  0.706576
# 30   6.300533   6.9  0.599467
# 31  22.215383  22.2 -0.015383
# 32   7.105490   7.6  0.494510
# 33   9.698797   9.2 -0.498797
# 34  17.848858  17.1 -0.748858
# 35  11.268248  10.4 -0.868248
# 36  20.618843  22.6  1.981157
# 37   7.400877   6.6 -0.800877
# 38   8.756179   8.5 -0.256179
# 39  15.788710  15.6 -0.188710
# 40  20.191986  19.6 -0.591986
# 41  11.010208  10.9 -0.110208
# 42   9.225657   7.3 -1.925657
# 43  22.133427  23.2  1.066573
# 44  17.083018  16.6 -0.483018
# 45  15.033804  15.2  0.166196
# 46  16.701916  19.7  2.998084
# 47  10.251219   8.7 -1.551219
# 48  12.453942  10.3 -2.153942
# 49  17.784928  16.9 -0.884928

# %%
res_df['error'].mean()
# Out:
# 0.0585100594010299

# %%
length = y_pred.shape[0] #  
x = np.linspace(0,length,length)

plt.figure(figsize=(10,7))
plt.plot(x, y_test, label='real y')
plt.plot(x, y_pred, label="predicted y'")
plt.legend(loc=2);

# %%
#misuro l'errore del mio modello
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error 
r2score= r2_score(y_test, y_pred)
mae=mean_absolute_error(y_test, y_pred)
mse=mean_squared_error(y_test, y_pred)
rmse=mean_squared_error(y_test,y_pred,squared=False)

print('R2_score:', r2score)
print('MAE:',mae)
print('MSE:',mse)
print('RMSE',rmse)
# Out:
# R2_score: 0.9303464725828599
# MAE: 0.9925653419688635
# MSE: 1.9603258108727855
# RMSE 1.4001163561907222
