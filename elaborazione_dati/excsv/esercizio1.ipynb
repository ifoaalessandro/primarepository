# %%
import pandas as pd
import numpy as np

df = pd.read_csv('energia.csv')
df
# Out:
#     ITTER107 Territorio  TIPO_DATO_CENERG  \
# 0         IT     Italia     ENER_SOUR_EXP
# 1         IT     Italia     ENER_SOUR_EXP
# 2         IT     Italia     ENER_SOUR_EXP
# 3         IT     Italia     ENER_SOUR_EXP
# 4         IT     Italia     ENER_SOUR_EXP
# ..       ...        ...               ...
# 296     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 297     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 298     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 299     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 300     ITG2   Sardegna  ENER_SOUR_EXP_AV
#
#                                              Tipo dato DOTAZIONI_A  \
# 0    spese delle famiglie per consumi energetici pe...         ALL
# 1    spese delle famiglie per consumi energetici pe...       H_OIL
# 2    spese delle famiglie per consumi energetici pe...         LPG
# 3    spese delle famiglie per consumi energetici pe...      ELECTR
# 4    spese delle famiglie per consumi energetici pe...       METAN
# ...

# %%
territorio = df['Territorio'].unique().tolist()
territorio
# Out:
# ['Italia',
#  'Nord-ovest',
#  'Piemonte',
#  "Valle d'Aosta / Vallée d'Aoste",
#  'Liguria',
#  'Lombardia',
#  'Nord-est',
#  'Trentino Alto Adige / Südtirol',
#  'Provincia Autonoma Bolzano / Bozen',
#  'Provincia Autonoma Trento',
#  'Veneto',
#  'Friuli-Venezia Giulia',
#  'Emilia-Romagna',
#  'Centro',
#  'Toscana',
#  'Umbria',
#  'Marche',
#  'Lazio',
#  'Mezzogiorno',
#  'Abruzzo',
#  'Molise',
#  'Campania',
#  'Puglia',
#  'Basilicata',
#  'Calabria',
#  'Sicilia',
#  'Sardegna']

# %%
df[df['Territorio'] == 'Sardegna']
# Out:
#     ITTER107 Territorio  TIPO_DATO_CENERG  \
# 292     ITG2   Sardegna     ENER_SOUR_EXP
# 293     ITG2   Sardegna     ENER_SOUR_EXP
# 294     ITG2   Sardegna     ENER_SOUR_EXP
# 295     ITG2   Sardegna     ENER_SOUR_EXP
# 296     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 297     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 298     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 299     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 300     ITG2   Sardegna  ENER_SOUR_EXP_AV
#
#                                              Tipo dato DOTAZIONI_A  \
# 292  spese delle famiglie per consumi energetici pe...         ALL
# 293  spese delle famiglie per consumi energetici pe...       H_OIL
# 294  spese delle famiglie per consumi energetici pe...         LPG
# 295  spese delle famiglie per consumi energetici pe...      ELECTR
# 296  spesa media effettiva delle famiglie per consu...       H_OIL
# 297  spesa media effettiva delle famiglie per consu...         LPG
# 298  spesa media effettiva delle famiglie per consu...      ELECTR
# ...

# %%
for i in territorio:
    df[df['Territorio'] == i].to_csv(f'csv_export/tabella_nuova_{i}.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[76], line 2
#       1 for i in territorio:
# ----> 2     df[df['Territorio'] == i].to_csv(f'csv_export/tabella_nuova_{i}.csv')
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('energia.csv')
df
# Out:
#     ITTER107 Territorio  TIPO_DATO_CENERG  \
# 0         IT     Italia     ENER_SOUR_EXP
# 1         IT     Italia     ENER_SOUR_EXP
# 2         IT     Italia     ENER_SOUR_EXP
# 3         IT     Italia     ENER_SOUR_EXP
# 4         IT     Italia     ENER_SOUR_EXP
# ..       ...        ...               ...
# 296     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 297     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 298     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 299     ITG2   Sardegna  ENER_SOUR_EXP_AV
# 300     ITG2   Sardegna  ENER_SOUR_EXP_AV
#
#                                              Tipo dato DOTAZIONI_A  \
# 0    spese delle famiglie per consumi energetici pe...         ALL
# 1    spese delle famiglie per consumi energetici pe...       H_OIL
# 2    spese delle famiglie per consumi energetici pe...         LPG
# 3    spese delle famiglie per consumi energetici pe...      ELECTR
# 4    spese delle famiglie per consumi energetici pe...       METAN
# ...

# %%
df[df['Territorio'] == 'Valle dAosta']
# Out:
# Empty DataFrame
# Columns: [ITTER107, Territorio, TIPO_DATO_CENERG, Tipo dato, DOTAZIONI_A, Fonte alimentazione, TIME, Seleziona periodo, Value, Flag Codes, Flags]
# Index: []

# %%
for i in territorio:
    df[df['Territorio'] == i].to_csv(f'csv_export/tabella_nuova_{i}.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[79], line 2
#       1 for i in territorio:
# ----> 2     df[df['Territorio'] == i].to_csv(f'csv_export/tabella_nuova_{i}.csv')
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
# ...

# %%
df['Territorio'].value_counts()
# Out:
# Italia                                17
# Toscana                               11
# Sicilia                               11
# Calabria                              11
# Basilicata                            11
# Puglia                                11
# Campania                              11
# Molise                                11
# Abruzzo                               11
# Mezzogiorno                           11
# Lazio                                 11
# Marche                                11
# Umbria                                11
# Centro                                11
# Nord-ovest                            11
# Emilia-Romagna                        11
# Friuli-Venezia Giulia                 11
# Veneto                                11
# Provincia Autonoma Trento             11
# Provincia Autonoma Bolzano / Bozen    11
# Trentino Alto Adige / Südtirol        11
# Nord-est                              11
# Lombardia                             11
# ...

# %%
for i in territorio:
    df[df['Territorio'] == i].to_csv(f'csv_export/tabella_nuova_{i}.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[81], line 2
#       1 for i in territorio:
# ----> 2     df[df['Territorio'] == i].to_csv(f'csv_export/tabella_nuova_{i}.csv')
#
# File c:\Users\ifoa\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
# ...

# %%
df = pd.read_csv("energia.csv")
diction = {"Valle d'Aosta / Vallée d'Aoste": "Valle_Aosta", 
           "Trentino Alto Adige / Südtirol": "Trentino",
           "Provincia Autonoma Bolzano / Bozen": "Bozen"}
df = df.replace({"Territorio": diction})
t = df["Territorio"].unique().tolist()

# %%
for i in t:
    df[df['Territorio'] == i].to_csv(f'csv_export/tabella_nuova_{i}.csv',index=False)

# %%
df['Territorio'].value_counts()
# Out:
# Italia                                17
# Toscana                               11
# Sicilia                               11
# Calabria                              11
# Basilicata                            11
# Puglia                                11
# Campania                              11
# Molise                                11
# Abruzzo                               11
# Mezzogiorno                           11
# Lazio                                 11
# Marche                                11
# Umbria                                11
# Centro                                11
# Nord-ovest                            11
# Emilia-Romagna                        11
# Friuli-Venezia Giulia                 11
# Veneto                                11
# Provincia Autonoma Trento             11
# Provincia Autonoma Bolzano / Bozen    11
# Trentino Alto Adige / Südtirol        11
# Nord-est                              11
# Lombardia                             11
# ...

# %%
for i in t:
    df[df['Territorio'] == i].to_excel(f'excel_export/tabella_nuova_{i}.xlsx',index=False)

# %%
import pandas as pd
import glob
import os

# %%
files = os.path.join("excel_export/", "*.xlsx")
files = glob.glob(files)
files
# Out:
# ['excel_export\\tabella_nuova_Abruzzo.xlsx',
#  'excel_export\\tabella_nuova_Basilicata.xlsx',
#  'excel_export\\tabella_nuova_Bozen.xlsx',
#  'excel_export\\tabella_nuova_Calabria.xlsx',
#  'excel_export\\tabella_nuova_Campania.xlsx',
#  'excel_export\\tabella_nuova_Centro.xlsx',
#  'excel_export\\tabella_nuova_Emilia-Romagna.xlsx',
#  'excel_export\\tabella_nuova_Friuli-Venezia Giulia.xlsx',
#  'excel_export\\tabella_nuova_Italia.xlsx',
#  'excel_export\\tabella_nuova_Lazio.xlsx',
#  'excel_export\\tabella_nuova_Liguria.xlsx',
#  'excel_export\\tabella_nuova_Lombardia.xlsx',
#  'excel_export\\tabella_nuova_Marche.xlsx',
#  'excel_export\\tabella_nuova_Mezzogiorno.xlsx',
#  'excel_export\\tabella_nuova_Molise.xlsx',
#  'excel_export\\tabella_nuova_Nord-est.xlsx',
#  'excel_export\\tabella_nuova_Nord-ovest.xlsx',
#  'excel_export\\tabella_nuova_Piemonte.xlsx',
#  'excel_export\\tabella_nuova_Provincia Autonoma Trento.xlsx',
#  'excel_export\\tabella_nuova_Puglia.xlsx',
# ...

# %%
df = pd.concat(map(pd.read_excel, files), ignore_index=True)
df.to_csv("csv_export/total1.csv", sep=";", index=False)
df.to_excel("excel_export/total1.xlsx", index=False)
